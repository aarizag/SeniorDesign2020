# %%
import spacy
# Load the spacy model that you have installed
nlp = spacy.load('en_core_web_md')
# process a sentence using the model
doc = nlp("This is some text that I am processing with Spacy")
# It's that simple - all of the vectors and words are assigned after this point
# Get the vector for 'text':
doc[3].vector
# Get the mean vector for the entire sentence (useful for sentence classification etc.)
doc.vector

# %%
from gensim.models import KeyedVectors
# Load vectors directly from the file
model = KeyedVectors.load_word2vec_format('/Users/norinchea/Desktop/wordEmbedding/Google/GoogleNews-vectors-negative300.bin', binary=True)
# Access vectors for specific words with a keyed lookup:
vector = model['easy']
# see the shape of the vector (300,)
vector.shape
# Processing sentences is not as simple as with Spacy:
vectors = [model[x] for x in "This is some text I am processing with Spacy".split(' ')]

# %%
import os
print(os.listdir('/Users/norinchea/Desktop/wordEmbedding/'))

# %%
#from gensim.models import Word2Vec
import gensim.models.word2vec as word2vec

from gensim.models import KeyedVectors

file_directory = '/Users/norinchea/Desktop/SeniorProject/wordEmbedding/Google/GoogleNews-vectors-negative300-SLIM.bin'


#GoogleNewsDataSet = KeyedVectors.load_word2vec_format(file_directory, binary=True)

model = KeyedVectors.load_word2vec_format(file_directory, binary=True)  

similarity = model.similarity('speaks', 'greets')

print(similarity)

# Numpy vector of word
example1 = model['computer']
example2 = model['laptop']

print(example1)
print(example2)
# Out:
# 0.5216603
# [ 1.07421875e-01 -2.01171875e-01  1.23046875e-01  2.11914062e-01
#  -9.13085938e-02  2.16796875e-01 -1.31835938e-01  8.30078125e-02
#   2.02148438e-01  4.78515625e-02  3.66210938e-02 -2.45361328e-02
#   2.39257812e-02 -1.60156250e-01 -2.61230469e-02  9.71679688e-02
#  -6.34765625e-02  1.84570312e-01  1.70898438e-01 -1.63085938e-01
#  -1.09375000e-01  1.49414062e-01 -4.65393066e-04  9.61914062e-02
#   1.68945312e-01  2.60925293e-03  8.93554688e-02  6.49414062e-02
#   3.56445312e-02 -6.93359375e-02 -1.46484375e-01 -1.21093750e-01
#  -2.27539062e-01  2.45361328e-02 -1.24511719e-01 -3.18359375e-01
#  -2.20703125e-01  1.30859375e-01  3.66210938e-02 -3.63769531e-02
#  -1.13281250e-01  1.95312500e-01  9.76562500e-02  1.26953125e-01
#   6.59179688e-02  6.93359375e-02  1.02539062e-02  1.75781250e-01
#  -1.68945312e-01  1.21307373e-03 -2.98828125e-01 -1.15234375e-01
#   5.66406250e-02 -1.77734375e-01 -2.08984375e-01  1.76757812e-01
# ...

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("/Users/norinchea/Desktop/SeniorProject/wordEmbedding/eCAPS.csv")
df.head()
# Out:
#    COMM_CD  COMM_CLS  COMM_ITM  COMM_GP  COMM_DET  \
# 0       35        35       NaN      NaN       NaN
# 1       37        37       NaN      NaN       NaN
# 2       40        40       NaN      NaN       NaN
# 3       45        45       NaN      NaN       NaN
# 4       50        50       NaN      NaN       NaN
#
#                                         COMM_DSCR_UP  ACT_INACT_FL  \
# 0  AIRCRAFT AND AIRPORT, EQUIPMENT, PARTS, AND SU...             0
# 1  AMUSEMENT, DECORATIONS, ENTERTAINMENT, TOYS, ETC.             0
# 2  ANIMALS, BIRDS, MARINE LIFE, AND POULTRY, INCL...             0
# 3          APPLIANCES AND EQUIPMENT, HOUSEHOLD  TYPE             0
# 4                         ART EQUIPMENT AND SUPPLIES             0
#
#                                                KEYWD  \
# 0  AIRCRAFT AND AIRPORT, EQUIPMENT, PARTS, AND SU...
# 1  AMUSEMENT, DECORATIONS, ENTERTAINMENT, TOYS, ETC.
# 2  ANIMALS, BIRDS, MARINE LIFE, AND POULTRY, INCL...
# ...

# %%
df["KEYWD"].str.split(",").str.get(0).str.title()
# Out:
# 0                                   Aircraft And Airport
# 1                                              Amusement
# 2                                                Animals
# 3                               Appliances And Equipment
# 4                             Art Equipment And Supplies
# 5                                              Abrasives
# 6                                        Acoustical Tile
# 7                                             Addressing
# 8                                 Agricultural Equipment
# 9             Agricultural Implement And Accessory Parts
# 10                       Air Compressors And Accessories
# 11                                      Air Conditioning
# 12     Automotive Vehicles And Related Transportation...
# 13                Automotive Shop Equipment And Supplies
# 14                                           Art Objects
# 15                Automotive Accessories For Automobiles
# ...

# %%
df["KEYWD"].str.split(" ")
# Out:
# 0      [AIRCRAFT, AND, AIRPORT,, EQUIPMENT,, PARTS,, ...
# 1      [AMUSEMENT,, DECORATIONS,, ENTERTAINMENT,, TOY...
# 2      [ANIMALS,, BIRDS,, MARINE, LIFE,, AND, POULTRY...
# 3       [APPLIANCES, AND, EQUIPMENT,, HOUSEHOLD, , TYPE]
# 4                        [ART, EQUIPMENT, AND, SUPPLIES]
# 5                                            [ABRASIVES]
# 6      [ACOUSTICAL, TILE,, INSULATING, MATERIALS,, AN...
# 7      [ADDRESSING,, COPYING,, MIMEOGRAPH,, AND, SPIR...
# 8      [AGRICULTURAL, EQUIPMENT,, IMPLEMENTS,, AND, A...
# 9       [AGRICULTURAL, IMPLEMENT, AND, ACCESSORY, PARTS]
# 10                  [AIR, COMPRESSORS, AND, ACCESSORIES]
# 11     [AIR, CONDITIONING,, HEATING,, AND, VENTILATIN...
# 12     [AUTOMOTIVE, VEHICLES, AND, RELATED, TRANSPORT...
# 13          [AUTOMOTIVE, SHOP, EQUIPMENT, AND, SUPPLIES]
# 14                                        [ART, OBJECTS]
# 15     [AUTOMOTIVE, ACCESSORIES, FOR, AUTOMOBILES,, B...
# ...

# %%
df.iloc[:,5].iloc[3]
# Out:
# 'APPLIANCES AND EQUIPMENT, HOUSEHOLD  TYPE'

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
filtered_list=[0]

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
import sys
# !{sys.executable} -m conda install --yes pyemd
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2019.07=py37_0
#   - defaults/osx-64::numba==0.44.1=py37h6440ff4_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/norinchea/anaconda3
#
#   added / updated specs:
#     - pyemd
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     anaconda-custom            |           py37_1           3 KB
#     ca-certificates-2020.1.1   |                0         125 KB
#     certifi-2019.11.28         |           py37_0         156 KB
#     openssl-1.1.1d             |       h1de35cc_3         3.4 MB
#     pyemd-0.5.1                |   py37h9537418_0          68 KB
# ...

# %%
import pandas as pd
UNSPSC = pd.ExcelFile("/Users/norinchea/Desktop/SeniorProject/wordEmbedding/UNSPSC.xlsx")

sheet_1 = pd.read_excel("/Users/norinchea/Desktop/SeniorProject/wordEmbedding/UNSPSC.xlsx",sheet_name=0)

# %%
sheet_1[11:]
# Out:
#              Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 11              Version        Key    Segment
# 12      UNSPSC v22_0601     100001   10000000
# 13      UNSPSC v22_0601     100002   10000000
# 14      UNSPSC v22_0601     100003   10000000
# 15      UNSPSC v22_0601     100004   10000000
# 16      UNSPSC v22_0601     100005   10000000
# 17      UNSPSC v22_0601     100006   10000000
# 18      UNSPSC v22_0601     100007   10000000
# 19      UNSPSC v22_0601     100008   10000000
# 20      UNSPSC v22_0601     100009   10000000
# 21      UNSPSC v22_0601     100010   10000000
# 22      UNSPSC v22_0601     100011   10000000
# 23      UNSPSC v22_0601     100012   10000000
# 24      UNSPSC v22_0601     100013   10000000
# 25      UNSPSC v22_0601     100014   10000000
# 26      UNSPSC v22_0601     100015   10000000
# 27      UNSPSC v22_0601     100016   10000000
# 28      UNSPSC v22_0601     100017   10000000
# 29      UNSPSC v22_0601     100018   10000000
# ...

# %%
from nltk.corpus import stopwords
def stopwords_remove(tokenized_words):
    #array with stopwords removed
    stopwords_removed = []

    # remove stop words from tokenized sentence
    stopwords_englishLanguage = set(stopwords.words('english'))
    
    for i in range(len(tokenized_words)):
        if tokenized_words[i] not in stopwords_englishLanguage:
            stopwords_removed.append(tokenized_words[i])
    
    return stopwords_removed

# %%
import pandas as pd
import os
df = pd.read_csv("/Users/norinchea/Desktop/SeniorProject/wordEmbedding/UNSPSC.csv")
df.head()
df.iloc[:,6].iloc[20]
# Out:
# 'Live animals'

# %%
import spacy
# Load the spacy model that you have installed
nlp = spacy.load('en_core_web_md')
# process a sentence using the model
doc = nlp("This is some text that I am processing with Spacy")
# It's that simple - all of the vectors and words are assigned after this point
# Get the vector for 'text':
doc[3].vector
# Get the mean vector for the entire sentence (useful for sentence classification etc.)
doc.vector
# Out:
# array([-5.36412969e-02,  2.79353321e-01, -1.05259977e-01, -1.76284965e-02,
#         1.34550199e-01,  1.92671806e-01,  5.50469756e-03, -2.39132687e-01,
#        -4.06342074e-02,  1.78010297e+00, -1.80772960e-01,  1.02661893e-01,
#         6.84069991e-02, -5.09319194e-02, -7.65837058e-02, -3.77540514e-02,
#         8.24129581e-03,  1.37752008e+00, -1.78934380e-01, -5.76109104e-02,
#         1.66338980e-02, -3.62196006e-02, -7.48579949e-02,  4.40651290e-02,
#        -2.65241470e-02,  2.41529979e-02,  9.79370065e-03, -1.13990309e-03,
#         1.59522101e-01, -1.56648397e-01, -9.12139937e-02,  9.11872908e-02,
#         1.07169405e-01, -1.08843103e-01, -7.94988051e-02, -4.74919155e-02,
#        -1.60613850e-01, -2.82304995e-02, -1.03425637e-01, -1.14933215e-01,
#         1.62531182e-01, -1.01342008e-01,  2.17013666e-03,  3.47881988e-02,
#        -6.34927005e-02,  2.44374484e-01, -3.01910043e-02, -1.46046979e-02,
# ...

# %%
from gensim.models import KeyedVectors
# Load vectors directly from the file
model = KeyedVectors.load_word2vec_format('/Users/norinchea/Desktop/SeniorProject/wordEmbedding/Google/GoogleNews-vectors-negative300.bin', binary=True)
# Access vectors for specific words with a keyed lookup:
vector = model['easy']
# see the shape of the vector (300,)
vector.shape
# Processing sentences is not as simple as with Spacy:
vectors = [model[x] for x in "This is some text I am processing with Spacy".split(' ')]

# %%
model.similarity('track','rail')
# Out:
# 0.2174111

# %%
model.similarity('taxi','car')
# Out:
# 0.46386763

# %%
model.most_similar('simple')
# Out:
# [('straightforward', 0.7460168600082397),
#  ('Simple', 0.7108174562454224),
#  ('uncomplicated', 0.6297484636306763),
#  ('simplest', 0.6171398162841797),
#  ('easy', 0.5990299582481384),
#  ('fairly_straightforward', 0.5893307328224182),
#  ('deceptively_simple', 0.5743066072463989),
#  ('simpler', 0.5537199974060059),
#  ('simplistic', 0.5516539216041565),
#  ('disarmingly_simple', 0.5365327000617981)]
